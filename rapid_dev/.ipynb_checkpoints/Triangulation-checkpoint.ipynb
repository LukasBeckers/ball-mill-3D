# %%
import sys
import os
from scipy import linalg
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import plotly.graph_objects as go
sys.path.append("..")
# Enable interactive plotting in Jupyter Notebook

from utils.detection_utils import *

# %%
run_name = "RUN3"
n_stickers = 5
file_number = 10
test_file = "10mm7.mp4"

spiegel_calib = "spiegel.mp4"
front_calib = "front.mp4"
stereo_calib = "stereo.mp4"

# %%
calibration_dir = f"../videos/{run_name}/calibration"
detection_dir = f"../videos/{run_name}/detection"
detection_files = os.listdir(detection_dir)
files = os.listdir(f"../videos/{run_name}/detection")
model = YOLO("../weights/best.pt")
if test_file is None:
    test_file = files[file_number]

sC = stereoCamera()
sC.load_from_yaml(f"{run_name}.yaml")
vL = videoLoader()
Dt1 = ballDetector()   
Dt2 = ballDetector()
sDt1 = stickerDetector(n_stickers)
sDt2 = stickerDetector(n_stickers)

print("File= ", test_file)
# Out:
# File=  10mm7.mp4

# %%
vL.load_video(f"../videos/{run_name}/detection/{test_file}")
frames = vL[30:-30]
stereo_coords = [[],[]]
sticker_stereo_cords = [[], []]
frame_count = []
for j, frame in enumerate(frames):

    frame1, frame2 = sC(frame)
    preds1 = model(frame1)
    preds2 = model(frame2)
   
    ballcoord1 = Dt1(preds1)
    ballcoord2 = Dt2(preds2)
    stickercoords1 = sDt1(preds1)
    stickercoords2 = sDt2(preds2)
    
    if ballcoord1 is None or ballcoord2 is None or stickercoords1 is None or stickercoords2 is None:
        continue
    if len([k for k in stickercoords1.keys() if k in stickercoords2.keys()]) < 3 :
        continue
    
    stereo_coords[0].append(ballcoord1)
    stereo_coords[1].append(ballcoord2)
    sticker_stereo_cords[0].append(stickercoords1)
    sticker_stereo_cords[1].append(stickercoords2)
    frame_count.append(j)
# Out:
# 0: 320x640 1 Ball, 5 Stickers, 128.4ms
# Speed: 300.9ms preprocess, 128.4ms inference, 403.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 20.1ms
# Speed: 1.6ms preprocess, 20.1ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# Warming up 0
# Warming up 0
#
# 0: 320x640 1 Ball, 5 Stickers, 20.2ms
# Speed: 2.5ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 20.8ms
# Speed: 1.6ms preprocess, 20.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# Warming up 1
# Warming up 1
#
# 0: 320x640 1 Ball, 5 Stickers, 20.1ms
# Speed: 2.8ms preprocess, 20.1ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 20.0ms
# Speed: 1.7ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# Warming up 2
# Warming up 2
#
# 0: 320x640 1 Ball, 5 Stickers, 20.6ms
# Speed: 3.0ms preprocess, 20.6ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# Warming up 3
# Warming up 3
#
# 0: 320x640 1 Ball, 5 Stickers, 20.1ms
# Speed: 2.8ms preprocess, 20.1ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 20.1ms
# Speed: 2.2ms preprocess, 20.1ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# Warming up 4
# Warming up 4
#
# 0: 320x640 1 Ball, 5 Stickers, 20.4ms
# Speed: 3.0ms preprocess, 20.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 20.1ms
# Speed: 2.8ms preprocess, 20.1ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
# Warming up 5
# Warming up 5
#
# 0: 320x640 1 Ball, 5 Stickers, 20.2ms
# Speed: 4.4ms preprocess, 20.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 20.3ms
# Speed: 1.8ms preprocess, 20.3ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# Warming up 6
# Warming up 6
#
# 0: 320x640 1 Ball, 5 Stickers, 20.4ms
# Speed: 5.4ms preprocess, 20.4ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 20.2ms
# Speed: 1.8ms preprocess, 20.2ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# Warming up 7
# Warming up 7
#
# 0: 320x640 1 Ball, 5 Stickers, 20.4ms
# Speed: 3.9ms preprocess, 20.4ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 20.2ms
# Speed: 1.7ms preprocess, 20.2ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
# Warming up 8
# Warming up 8
#
# 0: 320x640 1 Ball, 5 Stickers, 20.0ms
# Speed: 4.8ms preprocess, 20.0ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 20.8ms
# Speed: 2.0ms preprocess, 20.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# Warming up 9
# Warming up 9
#
# 0: 320x640 1 Ball, 5 Stickers, 19.8ms
# Speed: 3.8ms preprocess, 19.8ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.8ms
# Speed: 1.8ms preprocess, 19.8ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
# Warming up 10
# Warming up 10
#
# 0: 320x640 1 Ball, 5 Stickers, 19.8ms
# Speed: 4.1ms preprocess, 19.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.3ms
# Speed: 1.6ms preprocess, 19.3ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.9ms preprocess, 18.7ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.8ms preprocess, 18.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.9ms
# Speed: 2.9ms preprocess, 18.9ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 20.4ms
# Speed: 3.8ms preprocess, 20.4ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.9ms
# Speed: 3.1ms preprocess, 18.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.8ms preprocess, 18.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 22.3ms
# Speed: 2.7ms preprocess, 22.3ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.8ms preprocess, 18.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.6ms preprocess, 18.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.3ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.9ms preprocess, 18.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 3.0ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.8ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.9ms preprocess, 18.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.9ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.6ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.0ms preprocess, 18.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 3.3ms preprocess, 18.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.8ms preprocess, 18.8ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 4.4ms preprocess, 18.7ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.1ms
# Speed: 1.8ms preprocess, 19.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.5ms preprocess, 18.6ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 3.6ms preprocess, 18.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 4.4ms preprocess, 18.7ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.9ms preprocess, 18.6ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.1ms
# Speed: 1.6ms preprocess, 19.1ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.7ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.1ms
# Speed: 1.9ms preprocess, 19.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.0ms
# Speed: 3.5ms preprocess, 19.0ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 21.2ms
# Speed: 2.0ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.0ms
# Speed: 3.6ms preprocess, 19.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.9ms preprocess, 18.8ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.9ms
# Speed: 2.4ms preprocess, 18.9ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.6ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 4.1ms preprocess, 18.7ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.3ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.9ms preprocess, 18.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.5ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.8ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.6ms preprocess, 18.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.9ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.9ms
# Speed: 3.5ms preprocess, 18.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 4.0ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.7ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.7ms preprocess, 18.7ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.4ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.5ms preprocess, 18.5ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 3.5ms preprocess, 18.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 3.0ms preprocess, 18.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.0ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 4.5ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 3.4ms preprocess, 18.8ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.9ms preprocess, 18.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.9ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.9ms preprocess, 18.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.2ms
# Speed: 3.2ms preprocess, 19.2ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 3.5ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 11.4ms preprocess, 18.7ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.4ms preprocess, 18.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.5ms preprocess, 18.5ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.3ms
# Speed: 2.6ms preprocess, 19.3ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 3.2ms preprocess, 18.7ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.3ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.2ms
# Speed: 2.9ms preprocess, 19.2ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 3.6ms preprocess, 18.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.7ms preprocess, 18.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 3.3ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.4ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 4.2ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.8ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.8ms preprocess, 18.7ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.4ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.6ms preprocess, 18.5ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 3.5ms preprocess, 18.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.4ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.4ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.8ms preprocess, 18.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.2ms
# Speed: 2.2ms preprocess, 19.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.5ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.1ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 6.1ms preprocess, 18.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.7ms preprocess, 18.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 3.1ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.7ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.0ms preprocess, 18.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.9ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.0ms
# Speed: 2.5ms preprocess, 19.0ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.7ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.0ms
# Speed: 2.9ms preprocess, 19.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.7ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.2ms
# Speed: 6.0ms preprocess, 19.2ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.4ms
# Speed: 2.8ms preprocess, 19.4ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.4ms
# Speed: 1.8ms preprocess, 19.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 20.0ms
# Speed: 3.1ms preprocess, 20.0ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 21.6ms
# Speed: 2.7ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.2ms preprocess, 18.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 21.6ms
# Speed: 2.0ms preprocess, 21.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.9ms preprocess, 18.5ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.2ms preprocess, 18.6ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.3ms preprocess, 18.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.3ms
# Speed: 1.8ms preprocess, 19.3ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.3ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.9ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.6ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.5ms preprocess, 18.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.2ms
# Speed: 3.2ms preprocess, 19.2ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.8ms preprocess, 18.6ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.0ms
# Speed: 2.7ms preprocess, 19.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.4ms preprocess, 18.8ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 3.5ms preprocess, 18.8ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.9ms
# Speed: 4.6ms preprocess, 19.9ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 4.0ms preprocess, 18.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 4.1ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.9ms preprocess, 18.6ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.5ms preprocess, 18.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.7ms preprocess, 18.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.7ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.7ms preprocess, 18.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.8ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.7ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.3ms preprocess, 18.7ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 4.0ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.6ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.8ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 3.0ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.9ms preprocess, 18.8ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.7ms preprocess, 18.8ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 3.1ms preprocess, 18.5ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.7ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.2ms preprocess, 18.7ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.5ms preprocess, 18.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.0ms
# Speed: 2.9ms preprocess, 19.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.0ms
# Speed: 2.8ms preprocess, 19.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.2ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.6ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.8ms preprocess, 18.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.4ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 4.7ms preprocess, 18.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 20.0ms
# Speed: 3.3ms preprocess, 20.0ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.9ms preprocess, 18.6ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.8ms preprocess, 18.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.9ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.4ms
# Speed: 1.6ms preprocess, 19.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.2ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.9ms preprocess, 18.6ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.0ms preprocess, 18.6ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 4.9ms preprocess, 18.6ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 4.1ms preprocess, 18.6ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.9ms preprocess, 18.8ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 3.8ms preprocess, 18.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.6ms
# Speed: 3.8ms preprocess, 19.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.6ms preprocess, 18.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.4ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.4ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.7ms preprocess, 18.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.6ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.5ms preprocess, 18.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.6ms preprocess, 18.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.6ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.8ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.6ms preprocess, 18.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.7ms
# Speed: 3.8ms preprocess, 19.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.2ms
# Speed: 2.8ms preprocess, 19.2ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.4ms
# Speed: 5.8ms preprocess, 19.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.3ms
# Speed: 3.1ms preprocess, 19.3ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.7ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.8ms preprocess, 18.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.0ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.9ms preprocess, 18.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.0ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.7ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.5ms preprocess, 18.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.1ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.7ms preprocess, 18.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.2ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 3.5ms preprocess, 18.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.6ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.2ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.5ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.7ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.8ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.4ms preprocess, 18.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 4.6ms preprocess, 18.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.6ms preprocess, 18.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# ...
#
# 0: 320x640 1 Ball, 5 Stickers, 19.4ms
# Speed: 2.0ms preprocess, 19.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.4ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 19.2ms
# Speed: 2.8ms preprocess, 19.2ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.1ms preprocess, 18.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.3ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.4ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.0ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.5ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.3ms preprocess, 18.7ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.7ms preprocess, 18.7ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.8ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.4ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.5ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.4ms preprocess, 18.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.8ms preprocess, 18.6ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 3.1ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.4ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.8ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.3ms preprocess, 18.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.4ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 3.0ms preprocess, 18.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 2.4ms preprocess, 18.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.9ms preprocess, 18.7ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.4ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.5ms preprocess, 18.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.9ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.3ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.6ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.9ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.6ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.8ms
# Speed: 1.5ms preprocess, 18.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.5ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.3ms preprocess, 18.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.4ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.7ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.3ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.5ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.5ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.5ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.5ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.7ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.4ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.9ms
# Speed: 3.2ms preprocess, 18.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.3ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.5ms preprocess, 18.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.8ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.4ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.4ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.5ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 1.5ms preprocess, 18.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.4ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.5ms
# Speed: 2.5ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.5ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.6ms
# Speed: 1.8ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 2.4ms preprocess, 18.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Ball, 5 Stickers, 18.7ms
# Speed: 1.5ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)

# %%
print(np.array(stereo_coords).shape)
print(len(frame_count))
# Out:
# (2, 434, 2)
# 434

# %%
def DLT(P1, P2, point1, point2):
        A = [point1[1] * P1[2, :] - P1[1, :],
             P1[0, :] - point1[0] * P1[2, :],
             point2[1] * P2[2, :] - P2[1, :],
             P2[0, :] - point2[0] * P2[2, :]
             ]
        A = np.array(A).reshape((4, 4))
        B = A.transpose() @ A
        U, s, Vh = linalg.svd(B, full_matrices=False)

        return Vh[3, 0:3] / Vh[3, 3]

def triangulate(SC, point1, point2):
    RT1 = np.concatenate([np.eye(3), [[0], [0], [0]]], axis=-1)
    RT2 = np.concatenate([SC.conf["rotation_matrix"][0], SC.conf["translation_matrix"][0]], axis=-1)

    P1 = SC.conf["camera_matrix"][0] @ RT1
    P2 = SC.conf["camera_matrix"][1] @ RT2

    coordinate = DLT(P1, P2, point1, point2)
    return coordinate

# %%
def compute_transform_matrix(points_A, points_B):
    """Calculates the transform matrix to transform any point of one coordinatesystem (3d) to another"""
    # Assuming points_A and points_B are numpy arrays with shape (N, 3)
    # where N is the number of points (N >= 3),
    # Reshaping the points
    points_A = np.array(points_A)
    points_B = np.array(points_B)
    points_A = points_A.T
    points_B = points_B.T

    # Calculate the centroids of both point sets
    centroid_A = np.mean(points_A, axis=1, keepdims=True)
    centroid_B = np.mean(points_B, axis=1, keepdims=True)

    # Compute the centered point sets
    centered_A = points_A - centroid_A
    centered_B = points_B - centroid_B

    # Compute the covariance matrix
    covariance_matrix = centered_A @ centered_B.T

    # Perform Singular Value Decomposition
    U, _, Vt = np.linalg.svd(covariance_matrix)

    # Calculate the rotation matrix
    rotation_matrix = Vt.T @ U.T

    # Calculate the translation vector
    translation_vector = centroid_B - rotation_matrix @ centroid_A

    # Create the transformation matrix
    transform_matrix = np.eye(4)
    transform_matrix[:3, :3] = rotation_matrix
    transform_matrix[:3, 3] = translation_vector.flatten()
    return transform_matrix

def transform_point(point, transform_matrix):
    """Transforms a point to a nother coordinate system (3d) based on a transform_matrix"""
    # point needs one extra dimension
    point = np.array([point])
    point_homogeneous = np.hstack((point, np.ones((1, 1))))
    new_point_homogeneous = transform_matrix @ point_homogeneous.T

    # Extract the transformed point in system B
    new_point = new_point_homogeneous[:3, :].T
    return new_point[0]

# %% [markdown]
# # Calculating the 3D Points

# %%
ball3d = [triangulate(sC, point1, point2) for point1, point2 in zip(stereo_coords[0], stereo_coords[1])]
sticker3d = []

for sticker_coords1, sticker_coords2 in zip(*sticker_stereo_cords):
    valid_points = [k for k in sticker_coords1.keys() & sticker_coords2.keys()]
    points = {k: triangulate(sC, sticker_coords1[k], sticker_coords2[k]) for k in valid_points}
    sticker3d.append(points)

# %%
# Removing the yar movement

fixedball3d = [ball3d[0]]
base_sticker_points = sticker3d[0]
sticker03d = [[v for v in base_sticker_points.values()]

for ball_point, sticker_points, in zip(ball3d[1:], sticker3d[1:]):
    valid_points = [k for k in base_sticker_points.keys() & sticker_points.keys()]
    transform_matrix = compute_transform_matrix([sticker_points[k] for k in valid_points], [base_sticker_points[k] for k in valid_points])
    ball_point_new = transform_point(ball_point, transform_matrix)
    sticker_point_new = transform_point(sticker_points[0], transform_matrix)
    #print("Diff", ball_point -ball_point_new)
    print("Stickerpoint diff", base_sticker_points[0] -sticker_point_new)
    fixedball3d.append(ball_point_ne
    sticker03d.append([transform_point(sticker_points[0], transform_matrix)])
# Out:
# Stickerpoint diff [-3.6979e-05  1.1019e-05  -5.588e-05]
# Stickerpoint diff [ 6.7749e-05 -2.6231e-05  6.5169e-05]
# Stickerpoint diff [-0.00010332 -4.7441e-05 -4.0162e-05]
# Stickerpoint diff [-0.00020327 -7.8332e-05 -4.3325e-05]
# Stickerpoint diff [-0.00029728 -7.0526e-05 -0.00012298]
# Stickerpoint diff [-0.00060081 -0.00010166  -0.0002729]
# Stickerpoint diff [-0.00074251 -0.00013544 -0.00035373]
# Stickerpoint diff [ -0.0010704 -0.00020415 -0.00061886]
# Stickerpoint diff [ -0.0012083 -0.00024056  -0.0006591]
# Stickerpoint diff [ -0.0013711 -0.00027245 -0.00073615]
# Stickerpoint diff [ -0.0015064 -0.00029376  -0.0007242]
# Stickerpoint diff [ -0.0015684 -0.00027175 -0.00079612]
# Stickerpoint diff [ -0.0017352 -0.00028869 -0.00090501]
# Stickerpoint diff [ -0.0018074 -0.00028437 -0.00095234]
# Stickerpoint diff [  -0.001807 -0.00027443 -0.00099216]
# Stickerpoint diff [ -0.0018583 -0.00028337 -0.00099945]
# Stickerpoint diff [  -0.001894 -0.00031344  -0.0010555]
# Stickerpoint diff [ -0.0018922 -0.00029956  -0.0010752]
# Stickerpoint diff [ -0.0017727 -0.00029365 -0.00095496]
# Stickerpoint diff [ -0.0014997 -0.00030813 -0.00070146]
# Stickerpoint diff [ -0.0014288 -0.00030191 -0.00072672]
# Stickerpoint diff [ -0.0010573 -0.00027674 -0.00044087]
# Stickerpoint diff [ -0.0010207 -0.00020847 -0.00050292]
# Stickerpoint diff [ -0.0009453 -0.00017216 -0.00041805]
# Stickerpoint diff [-0.00064015 -0.00019611 -0.00016662]
# Stickerpoint diff [-0.00037493 -0.00011372 -6.4609e-05]
# Stickerpoint diff [-0.00028101 -5.3611e-05 -7.1325e-05]
# Stickerpoint diff [-0.00016756 -4.0387e-05  -4.921e-05]
# Stickerpoint diff [ 2.8193e-05  -2.467e-05  6.8698e-05]
# Stickerpoint diff [-3.5509e-05  1.3483e-05 -3.9046e-05]
# Stickerpoint diff [ 4.1818e-05  1.3572e-05  2.3248e-05]
# Stickerpoint diff [ 2.3063e-05  1.8286e-05  1.5983e-05]
# Stickerpoint diff [ 8.8727e-05  3.2952e-05  9.9997e-05]
# Stickerpoint diff [ 7.5207e-05 -2.9821e-05  0.00012634]
# Stickerpoint diff [-5.7823e-06 -3.3262e-06 -7.5741e-06]
# Stickerpoint diff [-0.00012945 -4.3382e-05 -9.7311e-06]
# Stickerpoint diff [-0.00045879 -8.9056e-05 -0.00022402]
# Stickerpoint diff [-0.00055797 -0.00015959 -0.00029986]
# Stickerpoint diff [-0.00090916 -0.00017319 -0.00047376]
# Stickerpoint diff [-0.00099773 -0.00019806 -0.00054538]
# Stickerpoint diff [ -0.0013124 -0.00025791 -0.00070807]
# Stickerpoint diff [ -0.0014924 -0.00027587 -0.00081193]
# Stickerpoint diff [  -0.001601 -0.00029498 -0.00087165]
# Stickerpoint diff [ -0.0017689 -0.00026335 -0.00093779]
# Stickerpoint diff [ -0.0018062 -0.00029894  -0.0010019]
# Stickerpoint diff [ -0.0019111 -0.00028067  -0.0010534]
# Stickerpoint diff [ -0.0018975 -0.00028115  -0.0010274]
# Stickerpoint diff [ -0.0018994 -0.00028841  -0.0010338]
# Stickerpoint diff [ -0.0019427 -0.00029208  -0.0010981]
# Stickerpoint diff [ -0.0019889 -0.00025256  -0.0011269]
# Stickerpoint diff [ -0.0017264 -0.00025443 -0.00097633]
# Stickerpoint diff [ -0.0014607 -0.00026801 -0.00077718]
# Stickerpoint diff [ -0.0012353 -0.00024435 -0.00068732]
# Stickerpoint diff [ -0.0010402 -0.00022109 -0.00051004]
# Stickerpoint diff [-0.00089867  -0.0002271 -0.00034028]
# Stickerpoint diff [-0.00085121   -0.000208 -0.00030571]
# Stickerpoint diff [-0.00048052 -0.00014828 -0.00011766]
# Stickerpoint diff [-0.00027668 -0.00010641 -5.0004e-05]
# Stickerpoint diff [-0.00025116 -3.2469e-05 -9.6434e-05]
# Stickerpoint diff [-0.00014501 -1.4991e-05 -2.4158e-06]
# Stickerpoint diff [-8.9351e-05 -3.0965e-05 -5.2239e-05]
# Stickerpoint diff [-6.7416e-05  -4.751e-05 -4.4861e-05]
# Stickerpoint diff [ 1.6961e-05 -1.5927e-05  2.5394e-05]
# Stickerpoint diff [-1.2453e-05 -1.5476e-05  2.9968e-05]
# Stickerpoint diff [ 9.6691e-05  -1.412e-05  7.2929e-05]
# Stickerpoint diff [ 0.00015822 -1.4592e-05  0.00012228]
# Stickerpoint diff [ 6.5646e-05 -3.1229e-05  0.00014553]
# Stickerpoint diff [-0.00010966 -3.0534e-05  6.7307e-05]
# Stickerpoint diff [-0.00047324 -0.00010968 -0.00018569]
# Stickerpoint diff [-0.00062361 -0.00013564 -0.00030881]
# Stickerpoint diff [-0.00081404 -0.00017853 -0.00041459]
# Stickerpoint diff [ -0.0010341 -0.00020054 -0.00054318]
# Stickerpoint diff [ -0.0012737 -0.00024857 -0.00065357]
# Stickerpoint diff [ -0.0014752 -0.00023996 -0.00081637]
# Stickerpoint diff [ -0.0014137  -0.0002528 -0.00075054]
# Stickerpoint diff [ -0.0016429 -0.00027032 -0.00084781]
# Stickerpoint diff [ -0.0018094 -0.00027671 -0.00094056]
# Stickerpoint diff [ -0.0018127 -0.00024813  -0.0009774]
# Stickerpoint diff [ -0.0018422   -0.000271  -0.0010137]
# Stickerpoint diff [ -0.0019142 -0.00026384  -0.0010124]
# Stickerpoint diff [  -0.001833 -0.00027801 -0.00097587]
# Stickerpoint diff [ -0.0018058 -0.00026388  -0.0010101]
# Stickerpoint diff [ -0.0015755 -0.00025486 -0.00090176]
# Stickerpoint diff [ -0.0014463 -0.00024202 -0.00077344]
# Stickerpoint diff [ -0.0012494 -0.00023189 -0.00060473]
# Stickerpoint diff [ -0.0010968 -0.00023341 -0.00051031]
# Stickerpoint diff [-0.00099164 -0.00019051 -0.00040896]
# Stickerpoint diff [-0.00070225 -0.00016485 -0.00021372]
# Stickerpoint diff [-0.00034286 -9.0691e-05 -8.6004e-05]
# Stickerpoint diff [-0.00020446 -6.2073e-05  7.9383e-05]
# Stickerpoint diff [-0.00013093 -2.6157e-05  1.5398e-05]
# Stickerpoint diff [-4.7512e-05 -2.6589e-05 -4.7081e-05]
# Stickerpoint diff [ 0.00014045  -4.115e-06  0.00013279]
# Stickerpoint diff [ 0.00013261 -1.2017e-05  0.00014163]
# Stickerpoint diff [ 0.00011186 -1.1498e-05  1.0239e-05]
# Stickerpoint diff [ 0.00012654  9.6235e-06  0.00013594]
# Stickerpoint diff [ 9.8721e-05  2.4723e-05  8.7885e-05]
# Stickerpoint diff [ 2.3574e-05 -2.1755e-05  9.9283e-05]
# Stickerpoint diff [-6.2024e-05 -4.5804e-05  9.7494e-05]
# Stickerpoint diff [-0.00014434  -5.481e-05  4.5397e-05]
# Stickerpoint diff [-0.00054705  -0.0001025 -0.00024831]
# Stickerpoint diff [-0.00062549 -0.00012376 -0.00026766]
# Stickerpoint diff [-0.00091895 -0.00017736 -0.00044112]
# Stickerpoint diff [ -0.0011629  -0.0001941 -0.00059081]
# Stickerpoint diff [ -0.0013683  -0.0002001  -0.0007036]
# Stickerpoint diff [ -0.0014658 -0.00021147 -0.00080859]
# Stickerpoint diff [ -0.0015197 -0.00027776 -0.00079583]
# Stickerpoint diff [ -0.0017614 -0.00026416 -0.00092141]
# Stickerpoint diff [ -0.0018758 -0.00024745 -0.00097935]
# Stickerpoint diff [ -0.0019296 -0.00024044  -0.0010252]
# Stickerpoint diff [  -0.001918 -0.00026572  -0.0010235]
# Stickerpoint diff [ -0.0019507 -0.00027435  -0.0010612]
# Stickerpoint diff [ -0.0018423 -0.00031786  -0.0010495]
# Stickerpoint diff [ -0.0017542 -0.00029094  -0.0010072]
# Stickerpoint diff [ -0.0015452 -0.00025931 -0.00086387]
# Stickerpoint diff [ -0.0014106 -0.00025624 -0.00074868]
# Stickerpoint diff [ -0.0012338 -0.00024934 -0.00060194]
# Stickerpoint diff [-0.00099545 -0.00025108 -0.00048015]
# Stickerpoint diff [-0.00098022 -0.00017674 -0.00039527]
# Stickerpoint diff [-0.00066944  -0.0001764 -0.00018224]
# Stickerpoint diff [-0.00045168 -0.00010075 -9.0622e-05]
# Stickerpoint diff [  -0.000194 -6.4758e-05 -1.9157e-05]
# Stickerpoint diff [-0.00014263 -6.3741e-05  2.3882e-05]
# Stickerpoint diff [ -0.0001148 -6.1843e-05  7.1135e-06]
# Stickerpoint diff [-4.8894e-05 -5.3844e-05 -1.6995e-05]
# Stickerpoint diff [ 4.4906e-05 -2.4892e-05  1.1691e-05]
# Stickerpoint diff [ 4.2636e-05  -6.205e-06  1.2694e-05]
# Stickerpoint diff [-4.4353e-05  1.3188e-05  1.2956e-05]
# Stickerpoint diff [ 4.3291e-05 -2.6667e-05  0.00010879]
# Stickerpoint diff [-3.5882e-05 -6.5246e-05  6.0724e-05]
# Stickerpoint diff [-3.5511e-05 -3.4316e-05  9.2377e-05]
# Stickerpoint diff [-0.00019967 -7.1993e-05 -3.6915e-05]
# Stickerpoint diff [-0.00043024 -9.2609e-05   -0.000155]
# Stickerpoint diff [-0.00072264 -0.00016949  -0.0002901]
# Stickerpoint diff [-0.00096679 -0.00015706 -0.00050179]
# Stickerpoint diff [ -0.0011706  -0.0001725 -0.00059379]
# Stickerpoint diff [ -0.0013307 -0.00021298 -0.00069708]
# Stickerpoint diff [ -0.0015775 -0.00024581 -0.00085795]
# Stickerpoint diff [ -0.0014942 -0.00027269 -0.00076159]
# Stickerpoint diff [  -0.001718 -0.00026595 -0.00098593]
# Stickerpoint diff [ -0.0018241  -0.0002629  -0.0010517]
# Stickerpoint diff [ -0.0018994 -0.00027179  -0.0010936]
# Stickerpoint diff [ -0.0018642 -0.00027134  -0.0010311]
# Stickerpoint diff [ -0.0018863 -0.00026143  -0.0010062]
# Stickerpoint diff [ -0.0019227 -0.00023821   -0.001059]
# Stickerpoint diff [   -0.00169 -0.00026799 -0.00096725]
# Stickerpoint diff [  -0.001493 -0.00026575 -0.00086568]
# Stickerpoint diff [ -0.0013804 -0.00028309 -0.00079979]
# Stickerpoint diff [ -0.0011445 -0.00026342 -0.00055907]
# Stickerpoint diff [-0.00094094 -0.00024383 -0.00044333]
# Stickerpoint diff [-0.00092951 -0.00021846 -0.00037183]
# Stickerpoint diff [  -0.000749 -0.00014969 -0.00024497]
# Stickerpoint diff [-0.00029984 -8.9987e-05  -3.081e-05]
# Stickerpoint diff [-0.00022536  -2.997e-05 -5.0441e-05]
# Stickerpoint diff [-4.8343e-05  5.1188e-08  7.2162e-05]
# Stickerpoint diff [-5.2212e-05  -1.208e-05  7.7203e-06]
# Stickerpoint diff [-0.00014891  5.0361e-07  -6.912e-05]
# Stickerpoint diff [-2.1441e-05 -7.1058e-06 -6.0182e-07]
# Stickerpoint diff [-4.8812e-05 -7.1873e-06  1.3756e-06]
# Stickerpoint diff [-4.6683e-06  3.1803e-06  1.4956e-05]
# Stickerpoint diff [ 0.00013351 -1.3195e-05  5.2075e-06]
# Stickerpoint diff [  6.254e-05 -3.5655e-05   5.874e-05]
# Stickerpoint diff [-0.00011136 -3.4155e-05  6.3288e-05]
# Stickerpoint diff [-0.00023799 -7.9431e-05 -6.0876e-05]
# Stickerpoint diff [-0.00066502 -0.00012711 -0.00031294]
# Stickerpoint diff [-0.00088375 -0.00016892 -0.00044849]
# Stickerpoint diff [ -0.0011153 -0.00022195  -0.0006174]
# Stickerpoint diff [ -0.0013401  -0.0002153 -0.00075035]
# Stickerpoint diff [ -0.0015212 -0.00025532 -0.00083554]
# Stickerpoint diff [ -0.0015351  -0.0002436 -0.00078914]
# Stickerpoint diff [  -0.001745 -0.00029478 -0.00093007]
# Stickerpoint diff [ -0.0018226  -0.0002941 -0.00094928]
# Stickerpoint diff [ -0.0019007 -0.00027568 -0.00098354]
# Stickerpoint diff [ -0.0018807 -0.00027138 -0.00097586]
# Stickerpoint diff [  -0.001929 -0.00029357  -0.0010081]
# Stickerpoint diff [ -0.0019476  -0.0002745  -0.0010592]
# Stickerpoint diff [ -0.0019254  -0.0002997  -0.0010703]
# Stickerpoint diff [ -0.0016809 -0.00028329 -0.00091758]
# Stickerpoint diff [ -0.0015434 -0.00029287 -0.00084718]
# Stickerpoint diff [ -0.0012945 -0.00026432 -0.00066018]
# Stickerpoint diff [ -0.0012372  -0.0002643 -0.00052741]
# Stickerpoint diff [ -0.0010036 -0.00020981 -0.00046569]
# Stickerpoint diff [-0.00083207 -0.00019631 -0.00024973]
# Stickerpoint diff [-0.00056221 -0.00014184 -0.00018475]
# Stickerpoint diff [-0.00030069 -8.7838e-05 -8.2762e-05]
# Stickerpoint diff [-0.00022442 -2.7199e-05 -4.3485e-05]
# Stickerpoint diff [-7.7562e-05  1.4645e-05 -1.6552e-05]
# Stickerpoint diff [ 4.8971e-05 -9.1106e-06   1.739e-05]
# Stickerpoint diff [ 9.8266e-05  1.9597e-05   8.651e-05]
# Stickerpoint diff [ 0.00015778   2.855e-05   8.963e-05]
# Stickerpoint diff [ 0.00014915  2.1036e-05  9.8704e-05]
# Stickerpoint diff [ 0.00015296  3.6263e-05  8.9518e-05]
# Stickerpoint diff [ 0.00014015 -1.8802e-05  0.00015047]
# Stickerpoint diff [-7.0873e-05 -2.6473e-05  3.5869e-05]
# Stickerpoint diff [-0.00011382 -5.9906e-05 -1.7296e-05]
# Stickerpoint diff [-0.00042514 -5.9786e-05 -0.00018564]
# Stickerpoint diff [-0.00054769 -0.00012432  -0.0003094]
# Stickerpoint diff [-0.00082495 -0.00015896 -0.00040116]
# Stickerpoint diff [ -0.0010326 -0.00020748 -0.00061852]
# Stickerpoint diff [ -0.0012701 -0.00024799 -0.00071218]
# Stickerpoint diff [ -0.0014146 -0.00027201  -0.0008368]
# Stickerpoint diff [ -0.0014473 -0.00027232 -0.00074753]
# Stickerpoint diff [ -0.0016241 -0.00028376 -0.00080775]
# Stickerpoint diff [ -0.0017518 -0.00027539 -0.00090756]
# Stickerpoint diff [  -0.001809 -0.00028171 -0.00095688]
# Stickerpoint diff [ -0.0018194 -0.00029342 -0.00096201]
# Stickerpoint diff [ -0.0018456 -0.00028217 -0.00094726]
# Stickerpoint diff [ -0.0018755 -0.00030856  -0.0010452]
# Stickerpoint diff [ -0.0018477 -0.00029493  -0.0009995]
# Stickerpoint diff [ -0.0016216 -0.00028349 -0.00087169]
# Stickerpoint diff [ -0.0014852  -0.0002768 -0.00073139]
# Stickerpoint diff [ -0.0013679 -0.00026948 -0.00069149]
# Stickerpoint diff [ -0.0011697 -0.00028298 -0.00053718]
# Stickerpoint diff [     -0.001 -0.00022386 -0.00040972]
# Stickerpoint diff [-0.00084209 -0.00016734 -0.00035887]
# Stickerpoint diff [-0.00056191  -0.0001394 -0.00021093]
# Stickerpoint diff [-0.00030553 -8.8482e-05 -1.1744e-05]
# Stickerpoint diff [-0.00024803 -3.7715e-05  -8.986e-05]
# Stickerpoint diff [-0.00017724   9.654e-07 -5.9232e-05]
# Stickerpoint diff [-9.5152e-06 -2.8175e-05  3.4706e-05]
# Stickerpoint diff [-0.00013499 -1.0314e-05 -5.2419e-05]
# Stickerpoint diff [-8.2937e-05  5.6632e-06 -7.2984e-05]
# Stickerpoint diff [-9.5717e-05  -2.127e-05 -2.1235e-05]
# Stickerpoint diff [-4.6321e-05  -2.494e-05    6.86e-05]
# Stickerpoint diff [ 0.00010186 -4.1088e-05  0.00018828]
# Stickerpoint diff [-5.9972e-05 -5.4849e-05  5.1233e-05]
# Stickerpoint diff [-0.00018561  -1.109e-05 -5.7233e-05]
# Stickerpoint diff [-0.00047739 -8.6392e-05 -0.00022589]
# Stickerpoint diff [-0.00066948 -0.00014498 -0.00034622]
# Stickerpoint diff [-0.00092968 -0.00014366 -0.00048066]
# Stickerpoint diff [ -0.0010035 -0.00016539 -0.00047815]
# Stickerpoint diff [ -0.0012479 -0.00021235  -0.0006885]
# Stickerpoint diff [  -0.001449 -0.00025247 -0.00079591]
# Stickerpoint diff [ -0.0015749 -0.00026496 -0.00082526]
# Stickerpoint diff [ -0.0016644 -0.00026709 -0.00087031]
# Stickerpoint diff [ -0.0017924 -0.00028156 -0.00095204]
# Stickerpoint diff [  -0.001939 -0.00026306  -0.0010387]
# Stickerpoint diff [ -0.0019781 -0.00028709   -0.001031]
# Stickerpoint diff [ -0.0019157 -0.00029517 -0.00095768]
# Stickerpoint diff [ -0.0018541  -0.0002826 -0.00099062]
# Stickerpoint diff [ -0.0018911 -0.00027341 -0.00098379]
# Stickerpoint diff [ -0.0016752  -0.0002627 -0.00089072]
# Stickerpoint diff [ -0.0014742 -0.00022373 -0.00077432]
# Stickerpoint diff [ -0.0012656 -0.00020047 -0.00058922]
# Stickerpoint diff [ -0.0011138 -0.00022433  -0.0004815]
# Stickerpoint diff [-0.00082796 -0.00021301 -0.00037828]
# Stickerpoint diff [-0.00076222 -0.00019864 -0.00026692]
# Stickerpoint diff [-0.00033604 -0.00011331 -8.4985e-05]
# Stickerpoint diff [-0.00031732 -9.9673e-05 -1.8512e-05]
# Stickerpoint diff [-0.00019182 -6.3263e-05 -2.7329e-05]
# Stickerpoint diff [-0.00022267 -4.9313e-05 -9.1621e-05]
# Stickerpoint diff [-8.0022e-05 -1.6263e-05 -0.00010482]
# Stickerpoint diff [ 6.0416e-06 -8.6809e-06 -9.7463e-06]
# Stickerpoint diff [-2.9862e-05 -2.4809e-06 -6.3354e-05]
# Stickerpoint diff [ 5.7101e-05  2.1845e-05 -2.8009e-06]
# Stickerpoint diff [ 8.0487e-05  2.1409e-05  4.6623e-05]
# Stickerpoint diff [ 0.00011843  7.0121e-07  5.6596e-05]
# Stickerpoint diff [ 1.7918e-05 -7.5354e-06  7.2748e-05]
# Stickerpoint diff [-0.00018608 -7.9164e-05 -6.9841e-05]
# Stickerpoint diff [-0.00051166 -0.00010085 -0.00029451]
# Stickerpoint diff [-0.00064531 -0.00014809 -0.00040472]
# Stickerpoint diff [-0.00083705 -0.00017967 -0.00045236]
# Stickerpoint diff [ -0.0015103 -0.00023858 -0.00080694]
# Stickerpoint diff [ -0.0012756 -0.00019669 -0.00065589]
# Stickerpoint diff [ -0.0011188 -0.00020236 -0.00059485]
# Stickerpoint diff [ -0.0010644 -0.00019459 -0.00049959]
# Stickerpoint diff [-0.00081185 -0.00016569 -0.00027809]
# Stickerpoint diff [-0.00045949 -0.00013391 -7.9003e-05]
# Stickerpoint diff [-0.00018997 -9.5018e-05  4.4993e-05]
# Stickerpoint diff [-0.00015968 -3.7269e-06 -1.5226e-05]
# Stickerpoint diff [-0.00018798 -4.9441e-05 -3.8434e-05]
# Stickerpoint diff [-7.1081e-05 -4.5808e-05  8.7433e-06]
# Stickerpoint diff [ 1.2787e-05 -8.2333e-06  2.2985e-06]
# Stickerpoint diff [-7.3499e-06   9.004e-06 -1.8292e-05]
# Stickerpoint diff [-1.5778e-05  1.4941e-05 -1.5811e-05]
# Stickerpoint diff [ 5.7815e-05  3.4308e-05  6.6501e-05]
# Stickerpoint diff [ 8.0751e-05  3.9534e-05  0.00014624]
# Stickerpoint diff [-0.00010491 -4.9649e-05  5.0293e-05]
# Stickerpoint diff [-0.00024817 -6.7402e-05 -5.4898e-05]
# Stickerpoint diff [ -0.0005489 -0.00011035 -0.00026523]
# Stickerpoint diff [-0.00073206 -0.00015356 -0.00037964]
# Stickerpoint diff [-0.00091553 -0.00014725  -0.0005541]
# Stickerpoint diff [ -0.0011194 -0.00018928 -0.00059058]
# Stickerpoint diff [ -0.0013638 -0.00023735  -0.0007371]
# Stickerpoint diff [ -0.0014249 -0.00025701   -0.000759]
# Stickerpoint diff [ -0.0014474 -0.00027808 -0.00081321]
# Stickerpoint diff [ -0.0015064 -0.00027341   -0.000826]
# Stickerpoint diff [ 8.3976e-05 -2.9783e-05  0.00013546]
# Stickerpoint diff [-3.4016e-05 -2.2553e-05  5.3653e-05]
# Stickerpoint diff [-0.00026096 -6.4202e-05 -9.9855e-05]
# Stickerpoint diff [-0.00030386  -7.169e-05 -9.9355e-05]
# Stickerpoint diff [-0.00057275 -0.00010036 -0.00025183]
# Stickerpoint diff [-0.00074572  -0.0001556 -0.00034239]
# Stickerpoint diff [ -0.0019626 -0.00028473  -0.0010697]
# Stickerpoint diff [ -0.0016861 -0.00028545 -0.00091474]
# Stickerpoint diff [ -0.0015738  -0.0002482 -0.00085266]
# Stickerpoint diff [ -0.0013988 -0.00026501 -0.00069594]
# Stickerpoint diff [ -0.0012481 -0.00022436 -0.00061687]
# Stickerpoint diff [ -0.0010762 -0.00020833 -0.00051998]
# Stickerpoint diff [-0.00093729 -0.00017403 -0.00042238]
# Stickerpoint diff [-0.00059206 -0.00015485 -0.00020061]
# Stickerpoint diff [-0.00035402 -7.2556e-05 -0.00011132]
# Stickerpoint diff [-0.00011977 -2.1538e-05  2.7803e-05]
# Stickerpoint diff [-1.1214e-06 -1.1835e-06  8.0155e-05]
# Stickerpoint diff [ 1.4887e-05 -2.6306e-05  3.2392e-05]
# Stickerpoint diff [-4.1384e-06  1.2834e-05  -1.712e-05]
# Stickerpoint diff [   1.61e-05  6.4779e-06  1.9788e-05]
# Stickerpoint diff [ 7.3446e-05  1.2673e-05  6.7535e-05]
# Stickerpoint diff [ 4.1543e-06  1.1702e-05  6.0487e-05]
# Stickerpoint diff [ 0.00015418  6.4038e-06  0.00013427]
# Stickerpoint diff [ 8.7821e-05  1.9259e-05  4.5419e-05]
# Stickerpoint diff [ -7.654e-05 -4.4511e-05  5.3862e-05]
# Stickerpoint diff [-0.00028994 -3.8565e-05 -0.00012449]
# Stickerpoint diff [-0.00064251  -0.0001002 -0.00037227]
# Stickerpoint diff [-0.00080651 -0.00016512 -0.00044297]
# Stickerpoint diff [ -0.0010082 -0.00018545  -0.0005963]
# Stickerpoint diff [ -0.0012264 -0.00023426  -0.0007011]
# Stickerpoint diff [ -0.0015038 -0.00028352 -0.00086715]
# Stickerpoint diff [ -0.0015522 -0.00024703 -0.00086713]
# Stickerpoint diff [ -0.0016829 -0.00028315 -0.00089136]
# Stickerpoint diff [  -0.001763 -0.00030796 -0.00096989]
# Stickerpoint diff [ -0.0018376 -0.00028174  -0.0010036]
# Stickerpoint diff [ -0.0019024 -0.00028094  -0.0010153]
# Stickerpoint diff [ -0.0019659 -0.00028868  -0.0010528]
# Stickerpoint diff [ -0.0019631 -0.00028964  -0.0011192]
# Stickerpoint diff [  -0.001998 -0.00027471  -0.0010944]
# Stickerpoint diff [ -0.0016854 -0.00028265 -0.00088131]
# Stickerpoint diff [ -0.0014435 -0.00026641 -0.00076884]
# Stickerpoint diff [ -0.0012978 -0.00026085 -0.00064548]
# Stickerpoint diff [ -0.0010565 -0.00027615  -0.0004742]
# Stickerpoint diff [-0.00099365 -0.00020708 -0.00044981]
# Stickerpoint diff [-0.00085904 -0.00020685 -0.00034218]
# Stickerpoint diff [-0.00043916 -0.00011714 -8.9612e-05]
# Stickerpoint diff [-0.00031339 -0.00011168  2.8354e-06]
# Stickerpoint diff [-0.00022974 -7.7008e-05 -2.5317e-06]
# Stickerpoint diff [-0.00016252 -4.5041e-05  5.9823e-06]
# Stickerpoint diff [-7.6747e-05 -4.2423e-05 -1.5959e-05]
# Stickerpoint diff [-5.2584e-05 -4.3025e-05  1.5021e-05]
# Stickerpoint diff [ 2.9593e-06 -2.1381e-05  5.9752e-05]
# Stickerpoint diff [ 6.6793e-06 -2.1307e-05  4.4632e-05]
# Stickerpoint diff [ 6.3757e-05  1.1155e-05  0.00012576]
# Stickerpoint diff [ 0.00011571 -2.4828e-05  0.00015917]
# Stickerpoint diff [-4.9956e-05 -2.5545e-05  4.4418e-05]
# Stickerpoint diff [-0.00019529  -4.574e-05   1.752e-05]
# Stickerpoint diff [-0.00040743  -0.0001122 -0.00018245]
# Stickerpoint diff [ -0.0004776 -0.00014169 -0.00028143]
# Stickerpoint diff [-0.00081974 -0.00015714 -0.00041111]
# Stickerpoint diff [-0.00097451 -0.00017065 -0.00052184]
# Stickerpoint diff [ -0.0011647 -0.00021125 -0.00063618]
# Stickerpoint diff [ -0.0013622 -0.00023414 -0.00077749]
# Stickerpoint diff [ -0.0014096  -0.0002818 -0.00074269]
# Stickerpoint diff [  -0.001741 -0.00028017  -0.0009026]
# Stickerpoint diff [ -0.0017394 -0.00028472 -0.00089316]
# Stickerpoint diff [ -0.0018901 -0.00029485 -0.00098693]
# Stickerpoint diff [ -0.0018794 -0.00029391  -0.0010121]
# Stickerpoint diff [ -0.0019442 -0.00029492  -0.0010502]
# Stickerpoint diff [ -0.0019913 -0.00030016  -0.0010796]
# Stickerpoint diff [ -0.0020178 -0.00029589  -0.0011903]
# Stickerpoint diff [ -0.0017725 -0.00029884 -0.00097853]
# Stickerpoint diff [ -0.0015052 -0.00027422 -0.00077721]
# Stickerpoint diff [ -0.0013089 -0.00026336 -0.00063054]
# Stickerpoint diff [ -0.0010264 -0.00021962 -0.00047391]
# Stickerpoint diff [-0.00095398 -0.00020745 -0.00044837]
# Stickerpoint diff [-0.00058169 -0.00017173 -0.00019897]
# Stickerpoint diff [-0.00049142 -0.00014567 -0.00017332]
# Stickerpoint diff [-0.00025178 -9.4694e-05 -6.8693e-05]
# Stickerpoint diff [-0.00022271 -2.6437e-05 -0.00010556]
# Stickerpoint diff [-4.7691e-06 -2.5395e-05  4.4105e-06]
# Stickerpoint diff [ 0.00011106 -4.4838e-05  0.00013246]
# Stickerpoint diff [ 1.4159e-05 -4.3443e-06 -2.0107e-06]
# Stickerpoint diff [ 1.4958e-05  2.6918e-05 -2.7954e-05]
# Stickerpoint diff [  4.035e-05  1.9683e-05  1.1036e-05]
# Stickerpoint diff [ 1.4722e-05  2.3386e-05  7.7015e-05]
# Stickerpoint diff [ 0.00012594 -2.1721e-05  9.5575e-05]
# Stickerpoint diff [-2.4829e-05 -3.7401e-06  6.4718e-05]
# Stickerpoint diff [-4.8327e-05 -6.4159e-05  6.2537e-05]
# Stickerpoint diff [-0.00050568 -9.7116e-05 -0.00022674]
# Stickerpoint diff [-0.00067136 -0.00013518 -0.00029019]
# Stickerpoint diff [-0.00087695  -0.0001524 -0.00046415]
# Stickerpoint diff [ -0.0010396 -0.00019402 -0.00054238]
# Stickerpoint diff [ -0.0013076 -0.00026099 -0.00076424]
# Stickerpoint diff [ -0.0014203 -0.00027044 -0.00078243]
# Stickerpoint diff [ -0.0015751 -0.00029207  -0.0008305]
# Stickerpoint diff [ -0.0016485 -0.00027546 -0.00082649]
# Stickerpoint diff [ -0.0018176 -0.00027499 -0.00096966]
# Stickerpoint diff [  -0.001834  -0.0002725 -0.00095591]
# Stickerpoint diff [ -0.0019081 -0.00028795  -0.0010208]
# Stickerpoint diff [ -0.0019308 -0.00031496  -0.0010056]
# Stickerpoint diff [ -0.0017908 -0.00032286 -0.00099113]
# Stickerpoint diff [  -0.001766 -0.00029864 -0.00096943]
# Stickerpoint diff [ -0.0016291 -0.00026607 -0.00083916]
# Stickerpoint diff [ -0.0015094 -0.00028185 -0.00074268]
# Stickerpoint diff [ -0.0012974 -0.00023307 -0.00067449]
# Stickerpoint diff [ -0.0011022  -0.0002419 -0.00051621]
# Stickerpoint diff [ -0.0011015 -0.00015248 -0.00047715]
# Stickerpoint diff [ -0.0008211 -0.00016917 -0.00031912]
# Stickerpoint diff [-0.00043011  -0.0001275 -7.9189e-05]
# Stickerpoint diff [-0.00033141 -8.8298e-05 -9.3994e-05]
# Stickerpoint diff [-0.00025402 -2.6262e-05 -2.8899e-05]
# Stickerpoint diff [-0.00023992 -2.4842e-05 -0.00015333]
# Stickerpoint diff [-0.00016413 -1.4032e-05 -0.00010665]
# Stickerpoint diff [-8.6865e-05  1.1413e-06 -8.7916e-05]
# Stickerpoint diff [ -7.684e-05  1.0213e-05 -6.4511e-05]
# Stickerpoint diff [-3.1117e-05  2.1444e-05 -2.0131e-05]
# Stickerpoint diff [ 1.5802e-05 -2.6894e-05  4.7208e-05]
# Stickerpoint diff [  1.912e-06 -3.4118e-05  6.9077e-05]
# Stickerpoint diff [-6.1656e-05  -2.102e-05  5.2504e-05]
# Stickerpoint diff [-0.00022379 -5.8062e-05 -5.1982e-05]
# Stickerpoint diff [-0.00042058 -0.00013239 -9.0289e-05]
# Stickerpoint diff [-0.00071607   -0.000179 -0.00033915]
# Stickerpoint diff [-0.00086561 -0.00016985 -0.00041046]
# Stickerpoint diff [ -0.0011473 -0.00020604 -0.00061147]
# Stickerpoint diff [ -0.0014631 -0.00024653 -0.00080782]
# Stickerpoint diff [ -0.0014391 -0.00024969 -0.00077316]
# Stickerpoint diff [ -0.0014995 -0.00031065 -0.00080308]
# Stickerpoint diff [ -0.0016722 -0.00029454 -0.00085566]
# Stickerpoint diff [ -0.0018571 -0.00032189  -0.0010117]
# Stickerpoint diff [ -0.0019343 -0.00031777  -0.0010548]
# Stickerpoint diff [ -0.0019205 -0.00031765  -0.0010219]
# Stickerpoint diff [ -0.0018979 -0.00027615  -0.0009853]
# Stickerpoint diff [ -0.0018577 -0.00027854  -0.0010005]
# Stickerpoint diff [ -0.0017323  -0.0002729  -0.0009257]
# Stickerpoint diff [  -0.001555 -0.00028474  -0.0008314]
# Stickerpoint diff [  -0.001397 -0.00026043 -0.00075468]
# Stickerpoint diff [ -0.0012457 -0.00023592 -0.00059127]
# Stickerpoint diff [ -0.0010874 -0.00024247 -0.00050917]
# Stickerpoint diff [-0.00081877 -0.00020187  -0.0002833]
# Stickerpoint diff [-0.00052176 -0.00015333  -6.148e-05]
# Stickerpoint diff [-0.00043165  -9.286e-05  -0.0001066]
# Stickerpoint diff [ -0.0002602 -6.4744e-05 -2.6002e-05]
# Stickerpoint diff [-0.00014614 -5.2066e-05  5.3161e-06]
# Stickerpoint diff [ -1.587e-05 -2.0336e-05 -9.0677e-06]
# Stickerpoint diff [ 4.5116e-05 -1.8484e-06  2.9425e-05]

# %%
coords = np.array(ball3d)  # Update this line based on your actual data
coords_sticker = np.array([x for p in sticker3d for x in p.values()])
# Create line connections between sequential points
connections = [[a, b] for a, b in zip(range(len(coords)-1), range(1, len(coords)))]
coords = np.concatenate([coords, coords_sticker], 0)
print(coords.shape)
# Calculate max range to set equal axes
x_range = [coords[:, 0].min(), coords[:, 0].max()]
y_range = [coords[:, 1].min(), coords[:, 1].max()]
z_range = [coords[:, 2].min(), coords[:, 2].max()]

# Find the maximum range
max_range = max(x_range[1] - x_range[0], y_range[1] - y_range[0], z_range[1] - z_range[0])

# Calculate the mid points for each axis
x_mid = sum(x_range) / 2
y_mid = sum(y_range) / 2
z_mid = sum(z_range) / 2

# Set the range for each axis to be the max range centered around the mid point
x_range = [x_mid - max_range / 2, x_mid + max_range / 2]
y_range = [y_mid - max_range / 2, y_mid + max_range / 2]
z_range = [z_mid - max_range / 2, z_mid + max_range / 2]

# Create the figure object
fig = go.Figure()

# Add lines between connected points
for conn in connections:
    fig.add_trace(go.Scatter3d(
        x=[coords[conn[0], 0], coords[conn[1], 0]],
        y=[coords[conn[0], 1], coords[conn[1], 1]],
        z=[coords[conn[0], 2], coords[conn[1], 2]],
        mode='lines',
        line=dict(color='blue', width=2),
        name='Line'
    ))

# Add markers for each point
fig.add_trace(go.Scatter3d(
    x=coords[:, 0],
    y=coords[:, 1],
    z=coords[:, 2],
    mode='markers',
    marker=dict(size=1, color='red'),
    name='Points'
))

# Update plot appearance
fig.update_layout(
    title="3D Line Plot",
    scene=dict(
        xaxis_title='X Coordinate',
        yaxis_title='Y Coordinate',
        zaxis_title='Z Coordinate',
        xaxis=dict(range=x_range, autorange=False),
        yaxis=dict(range=y_range, autorange=False),
        zaxis=dict(range=z_range, autorange=False),
        aspectmode='manual'
        #,
        #aspectratio=dict(x=1, y=1, z=1)
    )
)

# Show the plot
fig.show()
# Out:
# (2604, 3)

# %%
coords = np.array(fixedball3d)  # Update this line based on your actual data

# Create line connections between sequential points
connections = [[a, b] for a, b in zip(range(len(coords)-1), range(1, len(coords)))]

# Calculate max range to set equal axes
x_range = [coords[:, 0].min(), coords[:, 0].max()]
y_range = [coords[:, 1].min(), coords[:, 1].max()]
z_range = [coords[:, 2].min(), coords[:, 2].max()]

# Find the maximum range
max_range = max(x_range[1] - x_range[0], y_range[1] - y_range[0], z_range[1] - z_range[0])

# Calculate the mid points for each axis
x_mid = sum(x_range) / 2
y_mid = sum(y_range) / 2
z_mid = sum(z_range) / 2

# Set the range for each axis to be the max range centered around the mid point
x_range = [x_mid - max_range / 2, x_mid + max_range / 2]
y_range = [y_mid - max_range / 2, y_mid + max_range / 2]
z_range = [z_mid - max_range / 2, z_mid + max_range / 2]

# Create the figure object
fig = go.Figure()

# Add lines between connected points
for conn in connections:
    fig.add_trace(go.Scatter3d(
        x=[coords[conn[0], 0], coords[conn[1], 0]],
        y=[coords[conn[0], 1], coords[conn[1], 1]],
        z=[coords[conn[0], 2], coords[conn[1], 2]],
        mode='lines',
        line=dict(color='blue', width=2),
        name='Line'
    ))

# Add markers for each point
fig.add_trace(go.Scatter3d(
    x=coords[:, 0],
    y=coords[:, 1],
    z=coords[:, 2],
    mode='markers',
    marker=dict(size=1, color='red'),
    name='Points'
))

# Update plot appearance
fig.update_layout(
    title="3D Line Plot",
    scene=dict(
        xaxis_title='X Coordinate',
        yaxis_title='Y Coordinate',
        zaxis_title='Z Coordinate',
        xaxis=dict(range=x_range, autorange=False),
        yaxis=dict(range=y_range, autorange=False),
        zaxis=dict(range=z_range, autorange=False),
        aspectmode='manual'
        #,
        #aspectratio=dict(x=1, y=1, z=1)
    )
)

# Show the plot
fig.show()

# %% [markdown]
# # testing stereo vision results

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import numpy as np

coords = np.array(coords3d[0][:])  # Update this line based on your actual data

# Create line connections between sequential points
connections = [[a, b] for a, b in zip(range(len(coords)-1), range(1, len(coords)))]

# Calculate max range to set equal axes
x_range = [coords[:, 0].min(), coords[:, 0].max()]
y_range = [coords[:, 1].min(), coords[:, 1].max()]
z_range = [coords[:, 2].min(), coords[:, 2].max()]

# Find the maximum range
max_range = max(x_range[1] - x_range[0], y_range[1] - y_range[0], z_range[1] - z_range[0])

# Calculate the mid points for each axis
x_mid = sum(x_range) / 2
y_mid = sum(y_range) / 2
z_mid = sum(z_range) / 2

# Set the range for each axis to be the max range centered around the mid point
x_range = [x_mid - max_range / 2, x_mid + max_range / 2]
y_range = [y_mid - max_range / 2, y_mid + max_range / 2]
z_range = [z_mid - max_range / 2, z_mid + max_range / 2]
frame_numbers = np.array(frame_counts[0])
frame_numbers -= frame_numbers[0]

# Calculate total frames for 30 fps over the maximum frame index
total_frames = max(frame_numbers) + 1  # subtracting warmupsteps

# Create interpolated coordinates array
interpolated_coords = np.zeros((total_frames, 3))


for i in range(len(frame_numbers) - 1):
    start_frame, end_frame = frame_numbers[i], frame_numbers[i + 1]
    start_coords, end_coords = coords[i], coords[i + 1]
    for frame in range(start_frame, end_frame + 1):
        #print(frame, (1 - t) * start_coords + t * end_coords)
        t = (frame - start_frame) / (end_frame - start_frame)
        interpolated_coords[frame] = (1 - t) * start_coords + t * end_coords


print(interpolated_coords[:,0].min(), interpolated_coords[:,0].max())
print(interpolated_coords[:,1].min(), interpolated_coords[:,1].max())
print(interpolated_coords[:,2].min(), interpolated_coords[:,2].max())

# Using the interpolated coordinates for the animation
fig = go.Figure(
    data=[go.Scatter3d(
        x=[interpolated_coords[0, 0]], 
        y=[interpolated_coords[0, 1]], 
        z=[interpolated_coords[0, 2]],
        mode='markers',
        marker=dict(size=5, color='red')  # Adjust the size for visibility
    )],
    layout=go.Layout(
        scene=dict(
            xaxis=dict(range=[x_range[0], x_range[1]]),
            yaxis=dict(range=[y_range[0], y_range[1]]),
            zaxis=dict(range=[z_range[0], z_range[1]]),
            aspectmode='cube'  # Ensures all axes have the same scale
        ),
        updatemenus=[dict(
            type='buttons',
            showactive=False,
            buttons=[{'label': 'Play',
                      'method': 'animate',
                      'args': [None, {"frame": {"duration": 50, "redraw": True},
                                      "fromcurrent": True, "transition": {"duration": 30, "easing": "linear"}}]}]
        )]
    ),
    frames=[
        go.Frame(data=[go.Scatter3d(
            x=[coord[0]], y=[coord[1]], z=[coord[2]],
            mode='markers',
            marker=dict(size=5, color='red')  # Adjust the size to maintain the diameter of the ball
        )]) for coord in interpolated_coords
    ]
)

fig.show()
# Out:
# -0.27737493889412956 -0.2415031580767144
# -0.06107664554937043 -0.05823822388493083
# 3.534718559715113 3.5449712189935347

# %%
coords3d
# Out:
# array([   -0.26133,   -0.060881,      3.5419])
