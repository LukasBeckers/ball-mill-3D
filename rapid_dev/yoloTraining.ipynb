# %%
from ultralytics import YOLO
import sys
sys.path.append("..")
# Out:
# WARNING ⚠️ Ultralytics setting 'datasets_dir: .' must be different than 'runs_dir: .'. Please change one to avoid possible issues during training.
# View settings with 'yolo settings' or at '/home/lukas/.config/Ultralytics/settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Load a model
#model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("../weights/yolov8n.pt")  # load a pretrained model (recommended for training)

# %%
# Use the model
model.train(data="../config/dataset_configs/RUN3_0.yaml", epochs=200, save_dir="../runs")  # train the model
metrics = model.val()  # evaluate model performance on the validation set
path = model.export(format="onnx")  # export the model to ONNX format
print(path)
# Out:
# New https://pypi.org/project/ultralytics/8.2.5 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.43 🚀 Python-3.12.2 torch-2.3.0+cu121 CPU (13th Gen Intel Core(TM) i7-1365U)
# ...

# %% [markdown]
# # Testing the model

# %%
import os
import sys
from PIL import Image
sys.path.append("..")
# Enable interactive plotting in Jupyter Notebook

from utils.detection_utils import *

run_name = "RUN3"

spiegel_calib = "spiegel.mp4"
front_calib = "front.mp4"
stereo_calib = "stereo.mp4"

# %%
calibration_dir = f"../videos/{run_name}/calibration"
detection_dir = f"../videos/{run_name}/detection"
detection_files = os.listdir(detection_dir)
sC = stereoCamera()
sC.load_from_yaml(f"{run_name}.yaml")
vL = videoLoader()
vL.load_video(f"../videos/{run_name}/detection/{detection_files[0]}")

# %%
model(f"../videos/{run_name}/detection/{detection_files[10]}", save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/547) /home/lukas/projekte/BallMill3D/rapid_dev/../videos/RUN3/detection/big3.mp4: 384x640 2 Balls, 7 Stickers, 209.5ms
# video 1/1 (frame 2/547) /home/lukas/projekte/BallMill3D/rapid_dev/../videos/RUN3/detection/big3.mp4: 384x640 1 Ball, 7 Stickers, 139.7ms
# video 1/1 (frame 3/547) /home/lukas/projekte/BallMill3D/rapid_dev/../videos/RUN3/detection/big3.mp4: 384x640 2 Balls, 8 Stickers, 131.2ms
# ...
